# %% [markdown]
# # 그래픽:  Visaulization with Matplotlib & Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## Two interfaces for Matplotlib

# %%
x = np.linspace(0,10,100)# 0~10 사이100개의 점으로 구성된 행벡터 생성(간격은 10/99)
y = np.sin(x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
#         0.27872982,  0.37415123,  0.46575841,  0.55261747,  0.63384295,
#         0.7086068 ,  0.77614685,  0.83577457,  0.8868821 ,  0.92894843,
#         0.96154471,  0.98433866,  0.99709789,  0.99969234,  0.99209556,
#         0.97438499,  0.94674118,  0.90944594,  0.86287948,  0.8075165 ,
#         0.74392141,  0.6727425 ,  0.59470541,  0.51060568,  0.42130064,
#         0.32770071,  0.23076008,  0.13146699,  0.03083368, -0.07011396,
#        -0.17034683, -0.26884313, -0.36459873, -0.45663749, -0.54402111])

# %% [markdown]
# ### a simple plotting with MATLAB-style (plt interface) method

# %%
plt.plot(x, y) # x의 대응값에 대한 y 데이터의 2차원 선 플롯 생성      
plt.show() # 그래프 보여주기(처음 한번 사용할 때만)

# %% [markdown]
# ### Objected-oriendted interface: (by creating Figure and Axes objects)

# %%
fig = plt.figure() #전체적 모습, 속성 수정 가능
ax = plt.axes() # 좌표축을 만들어 현재 좌표축 설정한 figure당 한 axes objects
ax.plot(x, y)# x의 대응값에 대한 y 데이터의 2차원 선 플롯 생성

# %% [markdown]
# 단일 그림(axes) 하에 여러개의 내용을 포함함
# pyplot 방식

# %%
y1 = np.sin(x)
y2 = np.cos(x)
plt.plot(x,y1)   
plt.plot(x, y2)

# %% [markdown]
# ## Adjusting the Plot

# %% [markdown]
# Adjusting Line colors and styles

# %%
plt.plot(x, np.sin(x), color="red")     # specifying color by name

# %%
plt.plot(x, x + 0, linestyle='solid')

# %%
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted')

# %%
plt.plot(x, x + 4, linestyle = '-')     # for short, solid
plt.plot(x, x + 5, linestyle = '--')    # dashed
plt.plot(x, x + 6, linestyle = '-.')    # dashdot
plt.plot(x, x + 7, linestyle = ':')     # dotted

# %%
# combining the linestyle and color
plt.plot(x, x + 0, '-g')         # solid, green
plt.plot(x, x + 1, '--c')        # dashed, cyan
plt.plot(x, x + 2, '-.k')        # dashdt.black
plt.plot(x, x + 3, ':r')         # dotted, red

# %% [markdown]
# Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)   # x축은 -1 ~ 11
plt.ylim(-1.2, 1.2)    # y축은 -1.2 ~ 1.2
# Out:
# (-1.2, 1.2)

# %%
plt.plot(x, np.sin(x))       
plt.axis([-1, 11, -1.5, 1.5])    #([x 최소, x 최대, y 최소, y 최대])
# Out:
# [-1, 11, -1.5, 1.5]

# %% [markdown]
# labelling plots: titles, axis lables, and legends

# %%
plt.plot(x, np.sin(x))  
plt.title("A Sin Curve")     # adding labels , title, xlabel, ylabel
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)') #(x, y, 선스타일, 선 제목)
plt.plot(x, np.cos(x), ':b', label='cos(x)') #(x, y, 선스타일, 선 제목)
plt.legend()

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.axis([-1,11,-1.5,1.5])
plt.legend(['sin(x)', 'cos(x)'], loc=1) #이름 지정

# %% [markdown]
# ## Simple Scatter Plots

# %%
x = np.linspace(0,10,30)
plt.plot(x, np.sin(x), marker = 'o', linestyle = ' ', color = 'black')  # a scatter plot by plot function

# %%
plt.scatter(x,np.sin(x))    # scatter plot by scatter function

# %%
plt.scatter(x, np.sin(x), marker='*', color='black')

# %% [markdown]
# ##  다양한 형태의 plot 작성하기

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips[['sex','smoker','day','time']].describe()
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ### 히스토그램

# %%
#  MATLAB style plotting
plt.hist(tips['total_bill'], bins=10)  # 막대차트(x, 막대 갯수(nbins))    
plt.title("Histogram of Total Bill") 
plt.xlabel("Total_Bill")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#  누적 빈도 분석
plt.hist(tips['total_bill'], bins=30, cumulative=True)   # 누적 히스토그램 그리기
plt.title("Cumulative Histogram of Total Bill")
plt.xlabel("Total_Bill")
plt.ylabel("Cumulative Frequncy")
# Out:
# Text(0, 0.5, 'Cumulative Frequncy')

# %%
# 여러그룹의 히스토그램을 겹처서 그리기
plt.hist(tips[tips['sex']=='Male']['total_bill'], bins=10, color='blue', alpha=0.5, label="Male")#투명도
plt.hist(tips[tips['sex']=='Female']['total_bill'], bins=10, color='green', alpha=0.5, label ="Female")
plt.legend()

# %% [markdown]
# 막대그래프 (bar chart) 작성하기

# %%
x = ['Male', 'Female']
y = [25, 16]
plt.bar(x,y) #막대그래프(x, height)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.bar(tips['sex']) # height  정보 있어야함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-274b357bd29f> in <module>
# ----> 1 plt.bar(tips['sex'])
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
s_count = tips['sex'].value_counts()
s_count
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
type(s_count)
# Out:
# pandas.core.series.Series

# %%
plt.bar(s_count.index, s_count.values) 
plt.title("Bar Chart for number of sex")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.barh(s_count.index, s_count.values) # 옆으로 누운 막대 그래프
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# 원그래프 (pie chart) 그리기

# %%
d_count = tips['day'].value_counts() 
d_count
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
plt.pie(d_count.values, labels=d_count.index, autopct='%1.0f%%') 
#원그래프(x, 이름, 소수점 없이 비율 표시)
# Out:
# ([<matplotlib.patches.Wedge at 0x20856db0a88>,
#   <matplotlib.patches.Wedge at 0x20856dbb288>,
#   <matplotlib.patches.Wedge at 0x20856dbbb08>,
#   <matplotlib.patches.Wedge at 0x20856dc4408>],
#  [Text(0.47909423581850485, 0.990186201280084, 'Sat'),
#   Text(-1.0967192869113325, -0.08489290734035711, 'Sun'),
#   Text(0.3074340394718734, -1.0561649072820052, 'Thur'),
#   Text(1.06724906774893, -0.2664196452760947, 'Fri')],
#  [Text(0.26132412862827537, 0.5401015643345912, '36%'),
#   Text(-0.598210520133454, -0.04630522218564932, '31%'),
#   Text(0.16769129425738546, -0.5760899494265482, '25%'),
#   Text(0.5821358551357799, -0.14531980651423346, '8%')])

# %% [markdown]
# 박스플롯(boxplots)

# %%
plt.boxplot(tips["tip"])  #tips에 대한 박스플롯
plt.title("boxplot for the amount of tip")
plt.ylabel("tip($)")
# Out:
# Text(0, 0.5, 'tip($)')

# %%
plt.boxplot([tips[tips['sex']=='Female']['tip'],  #(x, y)
            tips[tips['sex']=='Male']['tip']],
            labels=['Female', "Male"])
plt.title("Boxplot of Tips by Sex")
plt.ylabel('Tip($)')
# Out:
# Text(0, 0.5, 'Tip($)')

# %% [markdown]
# 산점도에 따른 그래프

# %%
plt.scatter(tips['total_bill'], tips['tip'])
plt.title("Scatter plot between total_bill and tip")
plt.xlabel("Total_bill")
plt.ylabel("Tip($)")
# Out:
# Text(0, 0.5, 'Tip($)')

# %% [markdown]
# 다양한 범주형 변수를 고려한 산점도 작성

# %%
M_tips = tips[tips['sex']=="Male"]
F_tips = tips[tips['sex']=="Female"]
plt.scatter(x=M_tips["total_bill"], y=M_tips['tip'], label="Male")
plt.scatter(x=F_tips["total_bill"], y=F_tips['tip'], label="Female")
plt.title("Scatter plot between total-bill and tip")
plt.xlabel("Total_bills")
plt.ylabel("Tip($)")
plt.legend()

# %% [markdown]
# ##  여러개 그림 함께 그리기 (Multiple Subplots)

# %% [markdown]
# #### plt.subplot: simple grids of subplots

# %%
for i in range(1,5):
    plt.subplot(2,2,i) # 2 * 2 그리드로 나눈 후 i로 지정된 위치에 좌표축 만듦
    plt.text(0.5, 0.5, str((2, 2, i)), fontsize=18, ha="center") #점 (0.5,0.5)에 글쓰기

# %% [markdown]
# #### OO 방식으로 figure와 axes를 생성하여 그리기

# %%
x = np.linspace(0, 10, 100)
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.plot(x, np.sin(x))
ax2.plot(x, np.sin(x + np.pi / 4))
ax3.plot(x, np.sin(x + 2 * np.pi / 4))
ax4.plot(x, np.sin(x + 3 * np.pi / 4))

# %%
fig, ax = plt.subplots(2,2, sharex='col', sharey='row') #sharex, sharey 그리드 제거
ax[0,0].plot(x, np.sin(x))
ax[0,1].plot(x, np.sin(x + np.pi / 4))
ax[1,0].plot(x, np.sin(x + 2 * np.pi / 4))
ax[1,1].plot(x, np.sin(x + 3 * np.pi / 4))

# %%
ax
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020856374248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000208582281C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002085825D5C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020858293F08>]],
#       dtype=object)

# %% [markdown]
# #### 다양한 여러개의 그림을 함께 그리기 활용

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].hist(tips['total_bill'], bins=10)
ax[0,0].set_title("Histogram of total bill")
ax[0,1].hist(tips['tip'], bins=10)
ax[0,1].set_title("Histogram of tip")
ax[1,0].boxplot(tips['total_bill'])
ax[1,0].set_xlabel("total bill")
ax[1,1].boxplot(tips['tip'])
ax[1,1].set_xlabel("tip")
# Out:
# Text(0.5, 0, 'tip')

# %% [markdown]
# # Visualozaiton with Seaborn

# %% [markdown]
# 히스토그램 작성하기

# %%
sns.distplot(tips['total_bill']) #히스토그램과 확률밀도함수 표현

# %%
sns.distplot(tips['total_bill'], hist=False)   #hist 제거

# %% [markdown]
# 막대 그래프 (barplot)

# %%
sns.countplot(x='sex', data=tips) #변수 개수를 따로 산출 안해도 막대그래프 작성가능
# 데이터 프레임을 data 매개변수에 지정해줘야 함

# %%
sns.countplot(x='sex', hue='day', data=tips) #hue 는 옆에 표시하는 박스

# %%
sns.barplot(x='day', y='total_bill', data=tips) #y축 지정

# %% [markdown]
# matplotlib를 이용하여 barplot() 그리기

# %%
d_total_bill = tips.groupby('day')['total_bill'].mean()
d_total_bill
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
plt.bar(d_total_bill.index, d_total_bill.values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# 박스플롯 그리기

# %%
sns.boxplot(x='total_bill', data=tips) #x를 지정

# %%
sns.boxplot('total_bill', data=tips, orient="v")

# %%
sns.boxplot(x='sex', y='total_bill', data=tips)

# %%
sns.boxplot(x='sex', y='total_bill', hue='smoker', data=tips)

# %% [markdown]
# 산정도 그리기 (다양한 subset 그룹을 비교)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips) #그룹 산점도

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)

# %%
sns.scatterplot(x='total_bill', y='tip', style='sex', data=tips)

# %% [markdown]
# regression model을 산점도에 포함하여 작성함

# %%
sns.regplot(x='total_bill', y='tip', data=tips)

# %%
sns.regplot(x='total_bill', y='tip', ci=None, data=tips) #ci = None으로 주변 없앰

# %% [markdown]
# PairPlot()  관계 그래프 그리기

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex')

# %%
sns.pairplot(tips, corner=True)

# %% [markdown]
# FacetGrid()을 이용한 여러개의 그림을 한번에 작성하기

# %%
facet = sns.FacetGrid(data = tips, col='sex')
facet.map(sns.distplot, 'total_bill')

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet.map(sns.scatterplot, 'total_bill', 'tip')

# %%
facet = sns.FacetGrid(tips, col='day', row='sex', hue='smoker')
facet.map(sns.scatterplot, 'total_bill', 'tip')
